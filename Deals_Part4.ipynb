# %%
# load sql and pandas
# %load_ext sql
import pandas as pd
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# Connect to the deals database from deals part one
# %sql mysql+pymysql://root:mysql@localhost/deals
# Out:
# 'Connected: root@deals'

# %%
# %%sql
# # Execute a test query from deals part two
# SELECT *
# FROM Companies
# WHERE CompanyName like "%Inc.";
# Out:
# 111 rows affected.
# [(2, 'Abitibi-Price Inc.'),
#  (5, 'AirTouch Communications, Inc.'),
#  (6, 'Alex. Brown Inc.'),
#  (7, 'Allegheny Power System Inc.'),
#  (318, 'American Bankers Insurance Group Inc.'),
#  (319, 'American International Group Inc.'),
#  (11, 'American Medical Response, Inc.'),
#  (13, 'American Standard Companies, Inc.'),
#  (19, 'Apria Healthcare Group Inc.'),
#  (20, 'Ascend Communications, Inc.'),
#  (25, 'Barnett Banks, Inc.'),
#  (314, 'BDM International Inc.'),
#  (311, 'Beckman Instruments, Inc.'),
#  (31, 'Brooks Fiber Properties, Inc.'),
#  (33, 'Burlington Resources Inc.'),
#  (35, 'Calilber Systems Inc.'),
#  (37, 'Cardinal Health, Inc.'),
#  (303, 'Caterpillar Inc.'),
#  (41, 'Central Fidelity Banks Inc.'),
#  (42, 'Century Telephone Enterprises Inc.'),
#  (279, 'Ciba Specialty Chemicals Inc.'),
#  (50, 'Clear Channel Communications, Inc.'),
#  (52, 'Coca-Cola Enterprises Inc.'),
#  (64, 'CUC International Inc.'),
#  (68, 'Destec Energy, Inc.'),
#  (70, 'DowBrands Inc.'),
#  (71, 'DQE Inc.'),
#  (79, 'Evans Withycombe Residential Inc.'),
#  (81, 'Excel Communications, Inc.'),
#  (85, 'First Bank System, Inc.'),
#  (89, 'First USA, Inc.'),
#  (90, 'Fisher Scientific International Inc.'),
#  (91, 'Fleet Financial Group, Inc.'),
#  (93, 'Fox Kids Worldwide Inc.'),
#  (94, 'Fred Meyer Inc.'),
#  (96, 'GPU, Inc.'),
#  (97, 'GranCare Inc.'),
#  (99, 'Greenfield Industries, Inc.'),
#  (102, 'Healthsource, Inc.'),
#  (278, 'Hercules Inc.'),
#  (108, 'HFS Inc.'),
#  (109, 'Hicks, Muse, Tate & Furst Inc.'),
#  (112, 'Homeside, Inc.'),
#  (114, 'Household International Inc.'),
#  (115, 'HSN Inc.'),
#  (122, 'Integrated Health Services Inc.'),
#  (123, 'International Family Entertainment Inc.'),
#  (126, 'Investor Group led by Transworld Healthcare Inc.'),
#  (130, 'JP Foodservice Inc.'),
#  (131, 'Kennametal Inc.'),
#  (132, 'Keystone International Inc.'),
#  (138, 'Laidlaw Environmental Services, Inc.'),
#  (140, 'Laidlaw Inc.'),
#  (145, 'Living Centers of America Inc.'),
#  (150, 'Lucent Technologies Inc.'),
#  (151, "Mac Frugal's Bargains & Close-Outs Inc."),
#  (152, 'Mallinckrodt Inc.'),
#  (300, 'Mapco Inc.'),
#  (153, 'Marriott International, Inc.'),
#  (154, 'Marsh & McLennan Companies, Inc.'),
#  (155, 'McAfee Associates Inc.'),
#  (156, 'McClatchy Newspapers, Inc.'),
#  (159, 'MedPartners, Inc.'),
#  (162, 'MESA, Inc.'),
#  (163, 'Monterey Resources Inc.'),
#  (165, 'Morgan Stanley Group Inc.'),
#  (170, 'Nellcor Puritan Bennett Inc.'),
#  (317, 'Newcourt Credit Group Inc.'),
#  (282, 'Ocean Energy Inc.'),
#  (177, 'Outdoor Systems Inc.'),
#  (178, 'Overseas Shipholding Group, Inc.'),
#  (179, 'Pacific Telecom Inc.'),
#  (183, 'Patriot American Hospitality Inc.'),
#  (187, 'PhyCor Inc.'),
#  (194, 'Quality Food Centers Inc.'),
#  (197, 'Raycom Media, Inc.'),
#  (296, 'Renal Treatment Centers Inc.'),
#  (202, 'Revco D.S., Inc.'),
#  (204, 'Rohr Inc.'),
#  (205, 'Rollins Environmental Services, Inc.'),
#  (207, 'Rykoff Sexton Inc.'),
#  (208, 'S.C. Johnson & Son Inc.'),
#  (211, 'Salomon Inc.'),
#  (213, 'Scudder, Stevens & Clark Inc.'),
#  (217, 'SFX Broadcasting Inc.'),
#  (289, 'Showboat Inc.'),
#  (294, 'Simon DeBartolo Group Inc.'),
#  (280, 'Sonat Inc.'),
#  (226, 'Tambrands Inc.'),
#  (227, 'Tandem Computers Inc.'),
#  (228, 'Target Therapeutics, Inc.'),
#  (231, 'Telco Communications Group Inc.'),
#  (232, 'Tele-Communications, Inc.'),
#  (233, 'Tencor Instruments Inc.'),
#  (234, 'Texaco Inc.'),
#  (297, 'Total Renal Care Holdings Inc.'),
#  (315, 'TRW Inc.'),
#  (246, 'U.S. West, Inc.'),
#  (247, 'Union Pacific Resources Group Inc.'),
#  (248, 'United Waste Systems, Inc.'),
#  (249, 'Universal Outdoor Holdings Inc.'),
#  (250, 'Universal Studios, Inc.'),
#  (252, 'USA Waste Services Inc.'),
#  (255, 'Value Health, Inc.'),
#  (256, 'Vencor, Inc.'),
#  (257, 'Verifone, Inc.'),
#  (259, 'Vivra Inc.'),
#  (261, 'Wal-Mart Stores, Inc.'),
#  (262, 'Washington Mutual Inc.'),
#  (264, 'Western Resources, Inc.'),
#  (268, 'WorldCom, Inc.')]

# %%
# %%sql
# # 8 Create a reusable view based on the previous select query.
#
# DROP VIEW IF EXISTS CompanyDeals;
# CREATE VIEW CompanyDeals AS
# SELECT DEALS.DealName, PLAYERS.RoleCode, COMPANIES.CompanyName
# FROM COMPANIES
# 	JOIN PLAYERS ON (Companies.CompanyID = PLAYERS.CompanyID)
# 	JOIN DEALS ON (PLAYERS.DealID = DEALS.DealID)
# ORDER BY DealName;
# Out:
# 0 rows affected.
# 0 rows affected.
# []

# %%
# %%sql
#
# # 9 Create a view named DealValues that lists the DealID, total dollar value and number of parts for each deal.
# DROP VIEW IF EXISTS DealValues;
# CREATE VIEW DealValues AS
# SELECT DEALS.DealID, SUM(DollarValue) AS TotDollarValue, COUNT(PartNumber) AS NumParts
# FROM DEALS JOIN DEALPARTS ON (DEALS.DealID = DEALPARTS.DealID)
# GROUP BY DEALS.DealID
# ORDER BY DEALS.DealID;
#
# SELECT * from DealValues;
# Out:
# 0 rows affected.
# 0 rows affected.
# 151 rows affected.
# [(1, Decimal('5600.0000'), 1),
#  (2, Decimal('1700.0000'), 1),
#  (3, Decimal('1120.0000'), 1),
#  (4, Decimal('4000.0000'), 1),
#  (5, Decimal('1500.0000'), 1),
#  (6, Decimal('1600.0000'), 1),
#  (7, Decimal('1870.0000'), 1),
#  (8, Decimal('3700.0000'), 1),
#  (9, Decimal('1600.0000'), 1),
#  (10, Decimal('1200.0000'), 1),
#  (11, Decimal('1617.0000'), 1),
#  (12, Decimal('1360.0000'), 1),
#  (13, Decimal('1270.0000'), 1),
#  (14, Decimal('4210.0000'), 1),
#  (15, Decimal('1150.0000'), 1),
#  (16, Decimal('9700.0000'), 1),
#  (17, Decimal('1050.0000'), 1),
#  (18, Decimal('7000.0000'), 1),
#  (19, Decimal('3400.0000'), 1),
#  (20, Decimal('9500.0000'), 1),
#  (21, Decimal('6590.0000'), 1),
#  (22, Decimal('1700.0000'), 1),
#  (23, Decimal('1100.0000'), 1),
#  (24, Decimal('1355.0000'), 1),
#  (25, Decimal('10900.0000'), 1),
#  (26, Decimal('1650.0000'), 1),
#  (27, Decimal('1900.0000'), 1),
#  (28, Decimal('6500.0000'), 1),
#  (29, Decimal('1800.0000'), 1),
#  (30, Decimal('1200.0000'), 1),
#  (31, Decimal('1500.0000'), 1),
#  (32, Decimal('1230.0000'), 1),
#  (33, Decimal('2820.0000'), 1),
#  (34, Decimal('1000.0000'), 1),
#  (35, Decimal('1000.0000'), 1),
#  (36, Decimal('10500.0000'), 1),
#  (37, Decimal('2223.0000'), 1),
#  (38, Decimal('1800.0000'), 1),
#  (39, Decimal('1700.0000'), 1),
#  (40, Decimal('1000.0000'), 1),
#  (41, Decimal('3700.0000'), 1),
#  (42, Decimal('1500.0000'), 1),
#  (43, Decimal('2000.0000'), 1),
#  (44, Decimal('1100.0000'), 1),
#  (45, Decimal('1080.0000'), 1),
#  (46, Decimal('1300.0000'), 1),
#  (47, Decimal('2950.0000'), 1),
#  (48, Decimal('1100.0000'), 1),
#  (49, Decimal('8000.0000'), 1),
#  (50, Decimal('1500.0000'), 1),
#  (51, Decimal('9000.0000'), 1),
#  (52, Decimal('1770.0000'), 1),
#  (53, Decimal('7300.0000'), 1),
#  (54, Decimal('5000.0000'), 1),
#  (55, Decimal('1500.0000'), 1),
#  (56, Decimal('1300.0000'), 1),
#  (57, Decimal('1180.0000'), 1),
#  (58, Decimal('1075.0000'), 1),
#  (59, Decimal('1590.0000'), 1),
#  (60, Decimal('1100.0000'), 1),
#  (61, Decimal('2800.0000'), 1),
#  (62, Decimal('2625.0000'), 2),
#  (63, Decimal('2300.0000'), 1),
#  (64, Decimal('1400.0000'), 1),
#  (65, Decimal('2600.0000'), 1),
#  (66, Decimal('2500.0000'), 1),
#  (67, Decimal('3000.0000'), 1),
#  (68, Decimal('3000.0000'), 1),
#  (69, Decimal('1200.0000'), 1),
#  (70, Decimal('1392.0000'), 1),
#  (71, Decimal('1920.0000'), 1),
#  (72, Decimal('8260.0000'), 1),
#  (73, Decimal('1800.0000'), 1),
#  (74, Decimal('1900.0000'), 1),
#  (75, Decimal('6200.0000'), 1),
#  (76, Decimal('1389.0000'), 1),
#  (77, Decimal('1667.0000'), 1),
#  (78, Decimal('3250.0000'), 1),
#  (79, Decimal('3000.0000'), 1),
#  (80, Decimal('15500.0000'), 1),
#  (81, Decimal('4000.0000'), 1),
#  (82, Decimal('2500.0000'), 1),
#  (83, Decimal('1197.0000'), 1),
#  (84, Decimal('2000.0000'), 1),
#  (85, Decimal('1057.0000'), 1),
#  (86, Decimal('1060.0000'), 1),
#  (87, Decimal('4900.0000'), 1),
#  (88, Decimal('1200.0000'), 1),
#  (89, Decimal('1710.0000'), 1),
#  (90, Decimal('1100.0000'), 1),
#  (91, Decimal('1500.0000'), 1),
#  (92, Decimal('1200.0000'), 1),
#  (93, Decimal('1200.0000'), 1),
#  (94, Decimal('1780.0000'), 1),
#  (95, Decimal('2560.0000'), 1),
#  (96, Decimal('2600.0000'), 1),
#  (97, Decimal('2322.0000'), 1),
#  (98, Decimal('1450.0000'), 1),
#  (99, Decimal('2900.0000'), 1),
#  (100, Decimal('2237.0000'), 1),
#  (101, Decimal('12000.0000'), 1),
#  (102, Decimal('1000.0000'), 1),
#  (103, Decimal('78880.0000'), 3),
#  (104, Decimal('1300.0000'), 1),
#  (105, Decimal('1880.0000'), 1),
#  (106, Decimal('1600.0000'), 1),
#  (107, Decimal('9000.0000'), 1),
#  (108, Decimal('1000.0000'), 1),
#  (109, Decimal('1216.0000'), 1),
#  (110, Decimal('2350.0000'), 1),
#  (111, Decimal('2300.0000'), 1),
#  (112, Decimal('1700.0000'), 1),
#  (113, Decimal('1300.0000'), 1),
#  (114, Decimal('1450.0000'), 1),
#  (115, Decimal('18000.0000'), 1),
#  (116, Decimal('1490.0000'), 1),
#  (117, Decimal('3000.0000'), 2),
#  (118, Decimal('13000.0000'), 1),
#  (119, Decimal('3000.0000'), 1),
#  (120, Decimal('1250.0000'), 1),
#  (121, Decimal('1230.0000'), 1),
#  (122, Decimal('19500.0000'), 2),
#  (123, Decimal('3900.0000'), 2),
#  (124, Decimal('1000.0000'), 1),
#  (125, Decimal('8180.0000'), 1),
#  (126, Decimal('1700.0000'), 1),
#  (127, Decimal('3100.0000'), 1),
#  (128, Decimal('1800.0000'), 1),
#  (129, Decimal('1100.0000'), 1),
#  (130, Decimal('4100.0000'), 1),
#  (131, Decimal('1750.0000'), 1),
#  (132, Decimal('1525.0000'), 1),
#  (133, Decimal('1810.0000'), 1),
#  (134, Decimal('2200.0000'), 1),
#  (135, Decimal('1600.0000'), 1),
#  (136, Decimal('1000.0000'), 1),
#  (137, Decimal('6600.0000'), 1),
#  (138, Decimal('1050.0000'), 1),
#  (139, Decimal('6800.0000'), 1),
#  (140, Decimal('1000.0000'), 1),
#  (141, Decimal('2640.0000'), 2),
#  (142, Decimal('1330.0000'), 1),
#  (143, Decimal('3460.0000'), 1),
#  (144, Decimal('5300.0000'), 1),
#  (145, Decimal('1100.0000'), 1),
#  (146, Decimal('1000.0000'), 1),
#  (147, Decimal('1283.0000'), 1),
#  (148, Decimal('2000.0000'), 1),
#  (149, Decimal('2100.0000'), 1),
#  (150, Decimal('1200.0000'), 1),
#  (151, Decimal('1040.0000'), 1)]

# %%
# %%sql
# # 10 Create a view named DealSummary that lists the DealID, DealName, number of players, total dollar value, and number of parts for each deal.
# SELECT DEALS.DealID, DealName, COUNT(PlayerID) AS NumPlayers, TotDollarValue, NumParts
# FROM DEALS JOIN DealValues ON (DEALS.DealID = DealValues.DealID)
# 			JOIN Players ON (DEALS.DealID = Players.DealID)
# GROUP BY Deals.DealID;
# Out:
# 149 rows affected.
# [(1, 'ADT Limited', 3, Decimal('5600.0000'), 1),
#  (2, 'Alex. Brown Inc.', 2, Decimal('1700.0000'), 1),
#  (3, 'American Medical Response, Inc.', 2, Decimal('1120.0000'), 1),
#  (4, 'American Standard Companies, Inc.', 2, Decimal('4000.0000'), 1),
#  (5, 'Amphenol Corp.', 2, Decimal('1500.0000'), 1),
#  (6, 'Bankamerica Corp.', 1, Decimal('1600.0000'), 1),
#  (7, 'Berliner Kraft & Licht AG', 1, Decimal('1870.0000'), 1),
#  (8, 'Cascade Communications Corp.', 2, Decimal('3700.0000'), 1),
#  (9, 'Chancellor Broadcasting Comp.', 2, Decimal('1600.0000'), 1),
#  (10, 'Cifra S.A.', 2, Decimal('1200.0000'), 1),
#  (11, 'Coca Cola Bottling Co. of New York and Coca-Cola B', 2, Decimal('1617.0000'), 1),
#  (12, 'Dauphin Deposit Corp.', 2, Decimal('1360.0000'), 1),
#  (13, 'The Dow Chemical Company', 3, Decimal('1270.0000'), 1),
#  (14, 'DQE Inc.', 2, Decimal('4210.0000'), 1),
#  (15, 'Eller Media Corp.', 3, Decimal('1150.0000'), 1),
#  (16, 'The Energy Group PLC', 2, Decimal('9700.0000'), 1),
#  (17, 'First Financial Corp.', 2, Decimal('1050.0000'), 1),
#  (18, 'First USA, Inc.', 2, Decimal('7000.0000'), 1),
#  (19, 'Fort Howard Corp.', 2, Decimal('3400.0000'), 1),
#  (20, 'General Motors Corp.', 3, Decimal('9500.0000'), 1),
#  (21, 'Great Western Financial Corp.', 3, Decimal('6590.0000'), 1),
#  (22, 'Healthsource, Inc.', 2, Decimal('1700.0000'), 1),
#  (23, 'Hercules Inc. and Mallickrodt Inc', 2, Decimal('1100.0000'), 1),
#  (24, 'Heritage Media Corp.', 2, Decimal('1355.0000'), 1),
#  (25, 'HFS Inc.', 2, Decimal('10900.0000'), 1),
#  (26, 'Horizon/CMS Healthcare Corp.', 2, Decimal('1650.0000'), 1),
#  (27, 'International Family Entertainment Inc.', 5, Decimal('1900.0000'), 1),
#  (29, 'Johnson & Higgins', 2, Decimal('1800.0000'), 1),
#  (30, 'Keystone International Inc.', 3, Decimal('1200.0000'), 1),
#  (31, 'KU Energy Corporation', 2, Decimal('1500.0000'), 1),
#  (32, 'Laidlaw Inc.', 2, Decimal('1230.0000'), 1),
#  (33, 'Lincoln National Corporation', 2, Decimal('2820.0000'), 1),
#  (34, 'Living Centers of America Inc.', 3, Decimal('1000.0000'), 1),
#  (35, 'Minnesota Mining and Manufacturing Comp.', 2, Decimal('1000.0000'), 1),
#  (36, 'Morgan Stanley Group Inc.', 2, Decimal('10500.0000'), 1),
#  (37, 'Pacificorp', 2, Decimal('2223.0000'), 1),
#  (38, 'Parker & Parsley Petrolium Company', 2, Decimal('1800.0000'), 1),
#  (39, 'Read-Rite Corp.', 2, Decimal('1700.0000'), 1),
#  (40, 'Renaissance Hotel Group N.V.', 4, Decimal('1000.0000'), 1),
#  (41, 'Revco D.S., Inc.', 2, Decimal('3700.0000'), 1),
#  (42, 'Stone-Consolidated Corp.', 2, Decimal('1500.0000'), 1),
#  (43, 'Tambrands Inc.', 2, Decimal('2000.0000'), 1),
#  (44, 'Target Therapeutics, Inc.', 2, Decimal('1100.0000'), 1),
#  (45, 'Telco Communications Group Inc.', 3, Decimal('1080.0000'), 1),
#  (46, 'Tencor Instruments Inc.', 2, Decimal('1300.0000'), 1),
#  (47, 'Texas Instruments Inc.', 2, Decimal('2950.0000'), 1),
#  (48, 'Transamerica Corp.', 2, Decimal('1100.0000'), 1),
#  (49, 'The Unilever Group', 2, Decimal('8000.0000'), 1),
#  (50, 'United Waste Systems, Inc.', 2, Decimal('1500.0000'), 1),
#  (51, 'U.S. Bancorp', 2, Decimal('9000.0000'), 1),
#  (52, 'Uslife Corp.', 2, Decimal('1770.0000'), 1),
#  (53, 'U.S. Robotics Corp.', 2, Decimal('7300.0000'), 1),
#  (54, 'U.S. West, Inc.', 2, Decimal('5000.0000'), 1),
#  (55, 'Valero Energy Corp.', 2, Decimal('1500.0000'), 1),
#  (56, 'Value Health, Inc.', 2, Decimal('1300.0000'), 1),
#  (57, 'Verifone, Inc.', 2, Decimal('1180.0000'), 1),
#  (58, 'Viacom Inc.', 3, Decimal('1075.0000'), 1),
#  (59, 'Vivra Inc.', 2, Decimal('1590.0000'), 1),
#  (60, 'Wyndham Hotel Corp.', 3, Decimal('1100.0000'), 1),
#  (61, 'Yorkshire Electricity', 2, Decimal('2800.0000'), 1),
#  (62, 'Celebrity Cruise Lines Inc', 4, Decimal('2625.0000'), 2),
#  (63, 'Central Fidelity Banks Inc.', 2, Decimal('2300.0000'), 1),
#  (64, 'Cigna Corporation', 3, Decimal('1400.0000'), 1),
#  (65, 'Equitable of Iowa Companies', 2, Decimal('2600.0000'), 1),
#  (66, 'Falcon Drilling Co.', 2, Decimal('2500.0000'), 1),
#  (67, 'Imperial Chemical Industries PLC', 2, Decimal('3000.0000'), 1),
#  (68, 'The Louisiana Land and Exploration Company', 2, Decimal('3000.0000'), 1),
#  (69, 'Montgomery Securities', 2, Decimal('1200.0000'), 1),
#  (70, 'The Multicare Companies, Inc.', 2, Decimal('1392.0000'), 1),
#  (71, 'New York State Electric & Gas Corp.', 2, Decimal('1920.0000'), 1),
#  (72, 'Northrop Grumman Corp.', 2, Decimal('8260.0000'), 1),
#  (73, 'Octel Communications Corporation', 2, Decimal('1800.0000'), 1),
#  (74, 'Nellcor Puritan Bennett Inc.', 2, Decimal('1900.0000'), 1),
#  (75, 'Pennzoil Comp.', 2, Decimal('6200.0000'), 1),
#  (76, 'Rykoff Sexton Inc.', 3, Decimal('1389.0000'), 1),
#  (77, 'Scudder, Stevens & Clark Inc.', 2, Decimal('1667.0000'), 1),
#  (78, 'Signet Banking Corp.', 2, Decimal('3250.0000'), 1),
#  (79, 'Tandem Computers Inc.', 2, Decimal('3000.0000'), 1),
#  (80, 'Barnett Banks, Inc.', 2, Decimal('15500.0000'), 1),
#  (81, 'Beacon Properties Corp.', 2, Decimal('4000.0000'), 1),
#  (82, 'Bergen Brunswig Corp.', 2, Decimal('2500.0000'), 1),
#  (83, 'Chauvco Resources LTD.', 2, Decimal('1197.0000'), 1),
#  (84, 'Doubletree Corporation', 2, Decimal('2000.0000'), 1),
#  (85, 'Evans Withycombe Residential Inc.', 2, Decimal('1057.0000'), 1),
#  (86, 'Fisher Scientific International Inc.', 2, Decimal('1060.0000'), 1),
#  (87, 'W.R. Grace & Comp.', 2, Decimal('4900.0000'), 1),
#  (88, 'H&R Block Inc.', 2, Decimal('1200.0000'), 1),
#  (90, 'Monterey Resources Inc.', 2, Decimal('1100.0000'), 1),
#  (91, 'Ralston Purina Co.', 2, Decimal('1500.0000'), 1),
#  (92, 'SFX Broadcasting Inc.', 3, Decimal('1200.0000'), 1),
#  (93, 'Western National Corp.', 2, Decimal('1200.0000'), 1),
#  (94, 'Westin Hotels & Resorts', 2, Decimal('1780.0000'), 1),
#  (95, 'Westinghouse Electric Corp.', 2, Decimal('2560.0000'), 1),
#  (96, 'American Radio Systems Corp.', 2, Decimal('2600.0000'), 1),
#  (97, 'Amerisource Health Corp.', 2, Decimal('2322.0000'), 1),
#  (98, 'Apria Healthcare Group Inc.', 2, Decimal('1450.0000'), 1),
#  (99, 'Brooks Fiber Properties, Inc.', 2, Decimal('2900.0000'), 1),
#  (100, 'Calilber Systems Inc.', 2, Decimal('2237.0000'), 1),
#  (101, 'Coopers & Lybrand L.L.P.', 2, Decimal('12000.0000'), 1),
#  (102, 'Greenfield Industries, Inc.', 2, Decimal('1000.0000'), 1),
#  (103, 'MCI Communications Corporation', 4, Decimal('78880.0000'), 3),
#  (104, 'Network General Corp.', 2, Decimal('1300.0000'), 1),
#  (105, 'Powernet Victoria', 2, Decimal('1880.0000'), 1),
#  (106, 'The Quick & Reilly Group, Inc.', 2, Decimal('1600.0000'), 1),
#  (107, 'Salomon Inc.', 2, Decimal('9000.0000'), 1),
#  (108, 'Sony Corporation of America', 4, Decimal('1000.0000'), 1),
#  (109, 'Rohr Inc.', 2, Decimal('1216.0000'), 1),
#  (110, 'Tejas Gas Corp.', 3, Decimal('2350.0000'), 1),
#  (111, 'T&N PLC', 2, Decimal('2300.0000'), 1),
#  (112, 'Viacom Inc.', 2, Decimal('1700.0000'), 1),
#  (113, 'Advanta Corp.', 2, Decimal('1300.0000'), 1),
#  (114, 'Browning-Ferris Industries Inc.', 2, Decimal('1450.0000'), 1),
#  (115, 'Corestates Financial Corp.', 3, Decimal('18000.0000'), 1),
#  (116, 'Cowles Media Company', 2, Decimal('1490.0000'), 1),
#  (117, 'The Dow Chemical Company', 2, Decimal('3000.0000'), 2),
#  (118, 'Ernst & Young LLP', 2, Decimal('13000.0000'), 1),
#  (119, 'First Commerce Corp.', 2, Decimal('3000.0000'), 1),
#  (120, 'Healthsouth Corp.', 2, Decimal('1250.0000'), 1),
#  (121, 'Homeside, Inc.', 3, Decimal('1230.0000'), 1),
#  (122, 'ITT Corp.', 3, Decimal('19500.0000'), 2),
#  (123, 'Lin Television Corp.', 3, Decimal('3900.0000'), 2),
#  (124, "Mac Frugal's Bargains & Close-Outs Inc.", 2, Decimal('1000.0000'), 1),
#  (125, 'Medpartners, Inc.', 2, Decimal('8180.0000'), 1),
#  (126, 'Quality Food Centers Inc.', 3, Decimal('1700.0000'), 1),
#  (127, 'Ralphs Grocery Company', 3, Decimal('3100.0000'), 1),
#  (128, 'Safety-Kleen Corp.', 2, Decimal('1800.0000'), 1),
#  (129, 'Santa Fe Pacific Pipeline Partners', 2, Decimal('1100.0000'), 1),
#  (130, 'Seagram Company', 3, Decimal('4100.0000'), 1),
#  (131, 'Universal Outdoor Holdings Inc.', 2, Decimal('1750.0000'), 1),
#  (132, 'Westinghouse Electric Corp.', 2, Decimal('1525.0000'), 1),
#  (133, 'Allied Colloids Group PLC', 2, Decimal('1810.0000'), 1),
#  (134, 'American First Financial Insurance Group Inc.', 2, Decimal('2200.0000'), 1),
#  (135, 'AT&T Capital Corp.', 2, Decimal('1600.0000'), 1),
#  (136, 'BDM International', 2, Decimal('1000.0000'), 1),
#  (137, 'Central & South West Corp.', 2, Decimal('6600.0000'), 1),
#  (138, 'Coulter Corp.', 2, Decimal('1050.0000'), 1),
#  (139, 'First of America Bank Corp.', 2, Decimal('6800.0000'), 1),
#  (140, 'Hermann Healthcare System', 2, Decimal('1000.0000'), 1),
#  (141, 'Interstate Hotel Company', 3, Decimal('2640.0000'), 2),
#  (142, 'Lucas Varity PLC', 2, Decimal('1330.0000'), 1),
#  (143, 'MAPCO Inc.', 2, Decimal('3460.0000'), 1),
#  (144, 'Mercury Asset Management Group, P.L.C.', 2, Decimal('5300.0000'), 1),
#  (145, 'Renal Treatment Centers Inc.', 2, Decimal('1100.0000'), 1),
#  (146, 'Retail Property Trust', 5, Decimal('1000.0000'), 1),
#  (147, 'Showboat Inc.', 2, Decimal('1283.0000'), 1),
#  (148, 'Sodexho Alliance S.A.', 2, Decimal('2000.0000'), 1),
#  (149, 'Starwood Lodging Corp.', 2, Decimal('2100.0000'), 1),
#  (150, 'United Meridian Corp.', 2, Decimal('1200.0000'), 1),
#  (151, 'Zilkha Energy Co.', 2, Decimal('1040.0000'), 1)]

# %%
# %%sql
# # 11
# DROP VIEW IF EXISTS DealsByType;
# CREATE VIEW DealsByType AS
# SELECT DISTINCT DealTypes.TypeCode, COUNT(Deals.DealID) AS NumDeals, SUM(DealParts.DollarValue) as TotDollarValue
# FROM DealTypes
# 	LEFT JOIN Deals ON (DealTypes.DealID = Deals.DealID)
# 	JOIN DealParts ON (DealParts.DealID = Deals.DealID)
# GROUP BY DealTypes.TypeCode;
# Out:
# 0 rows affected.
# 0 rows affected.
# []

# %%
# %%sql
#
# # 12 Create a view called DealPlayers that lists the CompanyID, Name, and Role Code for each deal. Sort the players by the RoleSortOrder.
# DROP VIEW IF EXISTS DealPlayers;
# CREATE VIEW DealPlayers AS
# SELECT DealID, CompanyID, CompanyName, RoleCode
# FROM Players
# 	JOIN Deals USING (DealID)
#     JOIN COMPANIES USING (CompanyID)
#     JOIN ROLECODES USING (ROLECODE)
# ORDER BY RoleSortOrder;
# Out:
# 0 rows affected.
# 0 rows affected.
# []

# %%
# %%sql
#
# # 13 Create a view called DealsByFirm that lists the FirmID, Name, number of deals, and total value of deals for each firm.
# # Each firm should be listed, even if there are no deals for that firm. (Don't forget the comment and the select query.)
# SELECT FirmID, Firms.Name, COUNT(PLAYERS.DealId) AS NumDeals, SUM(TotDollarValue) AS TotValue
# FROM FIRMS
# 	JOIN PLAYERSUPPORTS USING (FirmID)
# 	JOIN PLAYERS USING (PlayerID)
# 	JOIN DealValues USING (DealID)
# GROUP BY FirmID;
# Out:
# 257 rows affected.
# [(2, 'Bryan Cave', 4, Decimal('84480.0000')),
#  (3, 'Buchanan Ingersol', 1, Decimal('1000.0000')),
#  (11, 'Dechert Price & Rhoads', 2, Decimal('81202.0000')),
#  (12, 'Davies, Ward & Beck', 1, Decimal('1000.0000')),
#  (19, 'Fulbright & Jaworski', 4, Decimal('4950.0000')),
#  (33, 'Swindler & Berlin', 2, Decimal('79960.0000')),
#  (36, 'Troutman Sanders', 1, Decimal('1870.0000')),
#  (41, 'Goulston & Storrs', 1, Decimal('1000.0000')),
#  (42, 'Goodman Phillips & Vineberg', 1, Decimal('1000.0000')),
#  (46, 'Robinson Silverman Pearce Aronsohn & Berman', 1, Decimal('3900.0000')),
#  (50, 'Schreck Morris', 1, Decimal('19500.0000')),
#  (62, 'Hughes Hubbard & Reed', 1, Decimal('12000.0000')),
#  (64, 'Hunton & Williams', 1, Decimal('1080.0000')),
#  (65, 'Hutchins, Wheeler & Ditmar', 1, Decimal('1230.0000')),
#  (66, 'Fried, Frank, Harris, Shriver & Jacobson', 25, Decimal('151823.0000')),
#  (67, 'Richards, Layton & Finger', 38, Decimal('208889.0000')),
#  (68, 'Sullivan & Cromwell', 55, Decimal('234340.0000')),
#  (69, 'Kramer, Levin, Naftalis, Nesse, Kamin & Frankel', 1, Decimal('5600.0000')),
#  (70, 'Freshfields', 5, Decimal('22530.0000')),
#  (71, 'Shearman & Sterling', 28, Decimal('168131.0000')),
#  (72, 'Piper & Marbury', 2, Decimal('2850.0000')),
#  (73, 'Debevoise & Plimpton', 12, Decimal('23230.0000')),
#  (74, 'Ropes & Gray', 1, Decimal('1120.0000')),
#  (75, 'Winthrop, Stimson, Putnam & Roberts', 2, Decimal('3600.0000')),
#  (76, 'Simpson Thacher & Bartlett', 39, Decimal('240471.0000')),
#  (77, 'Gibson, Dunn & Crutcher', 10, Decimal('25923.0000')),
#  (78, 'Weil, Gotshal & Manges', 11, Decimal('49488.0000')),
#  (79, 'Latham & Watkins', 10, Decimal('34183.0000')),
#  (80, 'Morris, Nichols, Arsht & Tunnell', 20, Decimal('148940.0000')),
#  (81, 'Paul, Weiss, Rifkind, Wharton & Garrison', 15, Decimal('191227.0000')),
#  (82, 'Tory, Tory, DesLauriers & Binnington', 2, Decimal('3117.0000')),
#  (83, 'Miller & Martin', 1, Decimal('1617.0000')),
#  (84, 'Long Aldridge Norman', 1, Decimal('1617.0000')),
#  (85, 'Stikeman, Elliot', 2, Decimal('3117.0000')),
#  (86, 'Pepper, Hamilton & Scheetz', 1, Decimal('1360.0000')),
#  (87, 'Skadden, Arps, Slate, Meagher & Flom', 45, Decimal('159730.0000')),
#  (88, 'Vinson & Elkins', 6, Decimal('13717.0000')),
#  (89, 'Chadbourne & Parke', 6, Decimal('13293.0000')),
#  (90, 'Brobeck, Phleger & Harrison', 2, Decimal('2860.0000')),
#  (91, 'Dewey Ballantine', 36, Decimal('238901.0000')),
#  (92, 'Akin, Gump, Strauss, Hauer & Feld', 3, Decimal('4050.0000')),
#  (93, 'Slaughter & May', 3, Decimal('19510.0000')),
#  (94, 'Milbank, Tweed, Hadley & McCloy', 3, Decimal('89660.0000')),
#  (95, 'Linklaters & Paines', 3, Decimal('91380.0000')),
#  (96, 'Hogan & Hartson', 3, Decimal('6439.0000')),
#  (97, 'Brown & Wood', 1, Decimal('7000.0000')),
#  (98, 'Kirkland & Ellis', 4, Decimal('16950.0000')),
#  (99, 'Cleary, Gottlieb, Steen & Hamilton', 16, Decimal('48079.0000')),
#  (100, 'White & Case', 6, Decimal('20870.0000')),
#  (101, 'Foster Pepper & Shefelman', 1, Decimal('6590.0000')),
#  (102, 'Sheehan Phinney Bass & Green', 1, Decimal('1700.0000')),
#  (103, 'Taft, Stettinius & Hollister', 1, Decimal('1100.0000')),
#  (104, 'King & Spalding', 1, Decimal('1100.0000')),
#  (106, 'Crouch & Hallett', 1, Decimal('1355.0000')),
#  (107, 'Squardon, Ellenoff, Plesent & Sheinfeld', 1, Decimal('1355.0000')),
#  (108, 'Troop, Meisinger, Steuer, Pasich', 1, Decimal('1900.0000')),
#  (109, 'Potter Anderson & Corroon', 3, Decimal('4200.0000')),
#  (110, 'Baker & Botts', 7, Decimal('18747.0000')),
#  (112, 'Watson Farley', 1, Decimal('2625.0000')),
#  (113, 'Davis Polk & Wardell', 25, Decimal('82524.0000')),
#  (114, 'Neal, Gerber & Eisenberg', 1, Decimal('2625.0000')),
#  (116, 'Wachtell, Lipton, Rosen & Katz', 30, Decimal('128135.0000')),
#  (119, 'Rogers & Wells', 4, Decimal('6405.0000')),
#  (120, 'Cravath, Swaine & Moore', 25, Decimal('260494.0000')),
#  (121, 'Kummer Kaempfer Bonner & Renshaw', 1, Decimal('19500.0000')),
#  (122, 'Liddell, Sapp, Zivley, Hill & LaBoon', 1, Decimal('1200.0000')),
#  (123, 'Gardner, Carton & Douglas', 1, Decimal('1500.0000')),
#  (124, 'Katten Muchin & Zavis', 3, Decimal('4150.0000')),
#  (125, 'Sutherland, Asbill & Brennan', 2, Decimal('4220.0000')),
#  (126, 'Perkins Coie', 1, Decimal('2820.0000')),
#  (127, 'Mayor, Day, Caldwell & Keeton', 1, Decimal('1000.0000')),
#  (128, 'Sidley & Austin', 5, Decimal('25480.0000')),
#  (129, 'Andrews & Kurth', 6, Decimal('6440.0000')),
#  (130, 'Powell, Goldstein, Frazer & Murphy', 2, Decimal('2000.0000')),
#  (132, 'Boles & Boles', 1, Decimal('2223.0000')),
#  (133, 'Carrerre & Denegre', 1, Decimal('2223.0000')),
#  (136, 'Stroock & Stroock & Lavan', 1, Decimal('1000.0000')),
#  (137, "O'Melveny & Myers", 4, Decimal('82880.0000')),
#  (138, 'Dinsmore & Shohl', 1, Decimal('2000.0000')),
#  (139, 'SJ Berwin & Co.', 1, Decimal('2000.0000')),
#  (140, 'Venture Law Group', 1, Decimal('1100.0000')),
#  (141, 'Munsch Hardt Kopf Harr & Dinan', 1, Decimal('1080.0000')),
#  (142, 'Wilcox & Savage', 1, Decimal('1080.0000')),
#  (143, 'Heller Ehrman White & McAuliffe', 2, Decimal('2500.0000')),
#  (144, 'Wilson, Sonsini, Goodrich & Rosati', 5, Decimal('7280.0000')),
#  (145, 'Wilmer, Cutler & Pickering', 3, Decimal('16100.0000')),
#  (146, 'Oscar Folger, solo practitioner', 1, Decimal('1500.0000')),
#  (147, 'Miller, Nash, Wiener, Hagen & Carlsen', 1, Decimal('9000.0000')),
#  (148, 'Dorsey & Whitney', 1, Decimal('9000.0000')),
#  (149, 'Mayer, Brown & Platt', 4, Decimal('12670.0000')),
#  (150, 'Gray Carey Ware & Friedenrich', 2, Decimal('11000.0000')),
#  (151, 'Willkie Farr & Gallagher', 9, Decimal('22309.0000')),
#  (152, 'Cooley Godward', 1, Decimal('1180.0000')),
#  (153, 'Drinker Biddle & Reath', 1, Decimal('1180.0000')),
#  (154, 'Goodwin, Procter & Hoar', 3, Decimal('7740.0000')),
#  (155, 'Ashurst Morris Crisp', 1, Decimal('2800.0000')),
#  (156, 'Cahill Gordon & Reindel', 4, Decimal('8747.0000')),
#  (157, 'Jones, Day, Reavis & Pogue', 18, Decimal('131547.0000')),
#  (160, 'Allen & Overy', 2, Decimal('8100.0000')),
#  (161, 'Alston & Bird', 2, Decimal('26180.0000')),
#  (164, 'Baker & MacKenzie', 1, Decimal('1200.0000')),
#  (173, 'Bracewell & Paterson', 2, Decimal('2140.0000')),
#  (177, 'Jones, Walker, Wachter, Poitevent, Carrere & Denegre', 1, Decimal('2223.0000')),
#  (188, 'LeBoeuf, Lamb, Greene & MacRae', 3, Decimal('6940.0000')),
#  (190, 'Locke, Purnell, Rain & Harrell', 1, Decimal('1100.0000')),
#  (196, 'McDermott, Will & Emery', 2, Decimal('2600.0000')),
#  (197, 'McGuire, Woods, Battle & Boothe', 2, Decimal('6650.0000')),
#  (199, 'Morgan, Lewis & Bockius', 3, Decimal('10500.0000')),
#  (200, 'Morrison & Foerster', 2, Decimal('4900.0000')),
#  (204, 'Orrick, Herrington & Sutcliffe', 2, Decimal('3300.0000')),
#  (205, 'Osler, Hoskin & Harcourt', 1, Decimal('1000.0000')),
#  (207, 'Pillsbury Madison & Sutro', 2, Decimal('6490.0000')),
#  (210, 'Quarles & Brady', 1, Decimal('1800.0000')),
#  (215, 'Blass & Driggs', 1, Decimal('1250.0000')),
#  (217, 'Alex. Brown & Sons Inc.', 2, Decimal('2850.0000')),
#  (219, 'Banamex', 1, Decimal('1200.0000')),
#  (220, 'Bankers Trust Corp.', 1, Decimal('1500.0000')),
#  (222, 'Bear, Stearns & Co., Inc.', 12, Decimal('66460.0000')),
#  (225, 'BT Wolfensohn', 5, Decimal('9500.0000')),
#  (227, 'Chase Securities Inc.', 4, Decimal('10470.0000')),
#  (228, 'CIBC Wood Gundy Inc.', 2, Decimal('2600.0000')),
#  (229, 'CIBC Wood Gundy Securities, Inc.', 1, Decimal('1617.0000')),
#  (234, 'Credit Suisse First Boston', 28, Decimal('101062.0000')),
#  (236, 'Daniels & Associates', 1, Decimal('1150.0000')),
#  (237, 'Deutsche Morgan Grenfell', 4, Decimal('8490.0000')),
#  (238, 'Dillon, Read & Co. Inc.', 3, Decimal('5910.0000')),
#  (239, 'Donaldson, Lufkin & Jenrette Securities Corp.', 12, Decimal('41785.0000')),
#  (240, 'Dresdner Kleinwort Benson', 1, Decimal('1870.0000')),
#  (243, 'Friedman, Billings, Ramsey & Co. Inc.', 1, Decimal('1075.0000')),
#  (244, 'Furman Selz Inc.', 1, Decimal('1300.0000')),
#  (246, 'Gleacher Natwest Inc.', 2, Decimal('3300.0000')),
#  (247, 'Goldman Sachs International', 2, Decimal('4720.0000')),
#  (248, 'Goldman, Sachs & Co.', 58, Decimal('259318.0000')),
#  (249, 'Greenhill & Co.', 3, Decimal('8500.0000')),
#  (251, 'Hambrecht & Quist', 1, Decimal('1300.0000')),
#  (257, 'Keefe, Bruyette & Woods, Inc.', 3, Decimal('6530.0000')),
#  (258, 'Lazard Brothers & Company Ltd.', 2, Decimal('15000.0000')),
#  (259, 'Lazard Freres & Co. LLC', 9, Decimal('120660.0000')),
#  (260, 'Lehman Brothers', 16, Decimal('121480.0000')),
#  (261, 'McDonald & Co.', 1, Decimal('1050.0000')),
#  (263, 'Merrill Lynch & Co.', 49, Decimal('165661.0000')),
#  (265, 'Montgomery Securities', 5, Decimal('26182.0000')),
#  (266, 'Morgan Stanley & Co. Inc.', 24, Decimal('156500.0000')),
#  (268, 'Morgan Stanley Dean Witter', 21, Decimal('80788.0000')),
#  (269, 'NationsBanc Capital Markets', 3, Decimal('3000.0000')),
#  (272, 'NM Rothschild', 2, Decimal('5100.0000')),
#  (273, 'PaineWebber Inc.', 3, Decimal('5129.0000')),
#  (274, 'Peter J. Solomon Company', 1, Decimal('2322.0000')),
#  (283, 'Salomon Brothers Inc.', 17, Decimal('136587.0000')),
#  (284, 'SBC Warburg', 1, Decimal('8000.0000')),
#  (287, 'Smith Barney Inc.', 15, Decimal('34331.0000')),
#  (291, 'The Blackstone Group L.P.', 2, Decimal('4140.0000')),
#  (293, 'UBS Securities', 6, Decimal('19373.0000')),
#  (294, 'Union Bank of Switzerland', 1, Decimal('1617.0000')),
#  (295, 'Wasserstein Perella & Co. Inc.', 7, Decimal('23164.0000')),
#  (297, 'William Blair & Company', 1, Decimal('1800.0000')),
#  (301, 'Bobby Blake and Associates', 1, Decimal('1100.0000')),
#  (302, 'Boxenbaum, Grates', 1, Decimal('1617.0000')),
#  (303, 'Brainerd Communicators', 1, Decimal('1600.0000')),
#  (304, 'Broadgate Consultants', 1, Decimal('2820.0000')),
#  (306, 'Burson-Marsteller', 6, Decimal('116080.0000')),
#  (308, 'Citigate Inc.', 1, Decimal('1590.0000')),
#  (309, 'Clark & Weinstock', 1, Decimal('3900.0000')),
#  (310, 'Copithorne & Bellows', 1, Decimal('1180.0000')),
#  (311, 'Corporate Communications', 1, Decimal('2900.0000')),
#  (312, 'Dewe Rogerson, Inc.', 1, Decimal('1500.0000')),
#  (314, 'Edelman Public Relations World', 2, Decimal('2383.0000')),
#  (316, 'Financial Dynamics', 2, Decimal('4610.0000')),
#  (319, 'Fleishman-Hillard, Inc.', 1, Decimal('5600.0000')),
#  (320, 'Gallagher PR', 1, Decimal('3700.0000')),
#  (321, 'Gavin Anderson & Company', 3, Decimal('9140.0000')),
#  (325, 'Jaffoni & Collins Inc.', 1, Decimal('1600.0000')),
#  (326, 'Kekst and Company', 29, Decimal('95958.0000')),
#  (327, 'Ketchum Public Relations', 2, Decimal('3000.0000')),
#  (330, 'Miller Shandwick Technologies', 1, Decimal('3000.0000')),
#  (333, 'Noonan/Russo Communications, Inc.', 1, Decimal('1650.0000')),
#  (339, 'Robinson Lerer & Montgomery', 3, Decimal('18800.0000')),
#  (342, 'Sard Verbinnen & Co., Inc.', 11, Decimal('131470.0000')),
#  (345, 'The Abernathy / MacGregor Group, Inc.', 21, Decimal('197217.0000')),
#  (346, 'The Atkins Company', 1, Decimal('1500.0000')),
#  (347, 'The Dilenschneider Group', 1, Decimal('2000.0000')),
#  (357, 'D.F. King & Co., Inc.', 22, Decimal('161219.0000')),
#  (361, 'Georgeson & Company Inc.', 25, Decimal('206087.0000')),
#  (364, 'Kissel-Blake Inc.', 2, Decimal('3200.0000')),
#  (365, 'MacKenzie Partners, Inc.', 8, Decimal('47740.0000')),
#  (366, 'McCormick & Pryor', 1, Decimal('1180.0000')),
#  (367, 'Morrow & Co., Inc.', 10, Decimal('22087.0000')),
#  (368, 'Nesbitt Burns Inc.', 1, Decimal('1500.0000')),
#  (370, 'Shareholder Communications Corporation', 1, Decimal('9700.0000')),
#  (371, 'Skinner & Co.', 2, Decimal('5000.0000')),
#  (372, 'Akin Gump', 1, Decimal('1150.0000')),
#  (373, 'Stoel Rives', 4, Decimal('16723.0000')),
#  (374, 'Squardon, Ellenoff', 1, Decimal('1900.0000')),
#  (375, 'Kramer, Levin, Naftalis & Frankel', 2, Decimal('5200.0000')),
#  (376, 'Tanner & Co. Inc.', 1, Decimal('3000.0000')),
#  (377, 'Munger, Tolles & Olson', 1, Decimal('1700.0000')),
#  (378, 'Young, Conaway, Stargatt & Taylor', 1, Decimal('1700.0000')),
#  (379, 'Rudnick & Wolfe', 1, Decimal('1057.0000')),
#  (380, 'Wiley, Rein & Fielding', 2, Decimal('5100.0000')),
#  (381, 'Peper, Martin, Jensen, Maichel and Hetlage', 1, Decimal('2900.0000')),
#  (382, 'J.P. Morgan & Co., Inc.', 11, Decimal('56887.0000')),
#  (383, 'Cazenove', 2, Decimal('4110.0000')),
#  (384, 'Cohane Rafferty Securities Inc.', 1, Decimal('1230.0000')),
#  (385, 'Hanover Capital Partners Ltd.', 1, Decimal('1230.0000')),
#  (386, 'BT Alex. Brown', 3, Decimal('11213.0000')),
#  (387, 'Waller Lansden Dortch & Davis', 1, Decimal('8180.0000')),
#  (388, 'Raymond James & Associates Inc.', 2, Decimal('3030.0000')),
#  (389, 'Morrison & Hecker', 1, Decimal('1100.0000')),
#  (391, 'Schulte Roth & Zabel', 1, Decimal('3900.0000')),
#  (453, 'Bartlit Beck Herman Palenchar & Scott', 1, Decimal('2350.0000')),
#  (454, 'Bennet Jones Verchere', 1, Decimal('1197.0000')),
#  (459, 'Corporate Investor Communications Inc.', 8, Decimal('19560.0000')),
#  (460, 'Correro Fishman Haygood Phelps Weiss Walmsey & Cas', 1, Decimal('3000.0000')),
#  (464, 'Dewey Square', 1, Decimal('19500.0000')),
#  (465, 'Dickstein Shapiro Morin & Oshinsky', 1, Decimal('1000.0000')),
#  (468, 'Evercore Group Inc.', 1, Decimal('6200.0000')),
#  (469, 'Evercore Partners', 1, Decimal('2560.0000')),
#  (470, 'Faegre & Benson', 1, Decimal('1490.0000')),
#  (473, 'Gibbs & Bruns', 1, Decimal('6200.0000')),
#  (475, 'Goodman and Carr', 1, Decimal('1000.0000')),
#  (477, 'Haskell Slaughter & Young', 1, Decimal('1250.0000')),
#  (478, 'Heller Ehrman', 1, Decimal('1150.0000')),
#  (479, 'in-house', 3, Decimal('7500.0000')),
#  (480, 'J.P. Morgan Securities Inc.', 1, Decimal('1100.0000')),
#  (481, 'Jose, Henry, Brantley & Keltner', 1, Decimal('6200.0000')),
#  (484, 'Lowenstein, Sandler, Kohl, Fisher & Boy-Ian', 1, Decimal('2500.0000')),
#  (487, 'Nyemaster, Goode, McLaughlin, Voigts, West, Hansel', 1, Decimal('2600.0000')),
#  (488, 'Proskauer Rose Goetz Mendelsohn', 1, Decimal('2625.0000')),
#  (489, 'RBC Dominion Securities Inc.', 2, Decimal('2814.0000')),
#  (490, 'Rosenberg & Liebentritt', 2, Decimal('5700.0000')),
#  (491, 'Rothschild Inc./NM Rothschild & Sons Ltd.', 1, Decimal('78880.0000')),
#  (492, 'Sonnenschein Nath & Rosenthal', 1, Decimal('1800.0000')),
#  (494, 'Sullivan & Worcester', 1, Decimal('2600.0000')),
#  (499, 'Williams, Mullen, Christian & Dobbins', 1, Decimal('2300.0000')),
#  (500, 'Wolf, Block, Schorr & Cohe', 1, Decimal('1300.0000')),
#  (501, 'Tillinghast', 1, Decimal('2600.0000')),
#  (502, 'Innisfree M&A Inc.', 4, Decimal('89200.0000')),
#  (503, 'Schroder Wertheim & Co.', 1, Decimal('1392.0000')),
#  (504, 'Huber Lawrence Abel', 1, Decimal('1920.0000')),
#  (505, 'Kantrow, Spaht, Weaver & Blitzer', 1, Decimal('6200.0000')),
#  (506, 'Mallesons, Stephens, Jacques', 1, Decimal('1880.0000')),
#  (507, 'Freehill, Hollingdale & Page', 1, Decimal('1880.0000')),
#  (508, 'Berlach, Israel & Liberman', 1, Decimal('1880.0000')),
#  (509, 'Liebowitz & Associates', 1, Decimal('1200.0000')),
#  (510, 'Blake, Cassels & Grayson', 1, Decimal('1600.0000')),
#  (511, 'Toronto Dominion', 1, Decimal('1600.0000')),
#  (512, 'Salomon Smith Barney', 2, Decimal('10060.0000')),
#  (513, 'BA Partners', 1, Decimal('1050.0000')),
#  (514, 'Howard & Howard', 1, Decimal('6800.0000')),
#  (515, 'Nationsbank ontgomery Securities', 1, Decimal('6800.0000')),
#  (516, 'Davis Wallis Foyster', 1, Decimal('1330.0000')),
#  (517, 'Riordan & McKenzie', 1, Decimal('1100.0000')),
#  (518, 'Duane, Morris & Heckscher', 1, Decimal('1100.0000')),
#  (519, 'Thompson, Hine & Flory', 1, Decimal('1000.0000')),
#  (520, 'Gordon Altman', 1, Decimal('1000.0000')),
#  (521, 'Societe Generale Securities Corporation', 1, Decimal('2000.0000')),
#  (522, 'Wolfensohn', 1, Decimal('1283.0000'))]
